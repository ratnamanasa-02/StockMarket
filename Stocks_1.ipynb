# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['AAPL']

# Set up End and Start times for data grab
tech_list = ['AAPL']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [AAPL]
company_name = ["APPLE"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-26  182.240005  182.759995  180.649994  181.160004  181.160004
# 2024-02-27  181.100006  183.919998  179.559998  182.630005  182.630005
# 2024-02-28  182.509995  183.119995  180.130005  181.419998  181.419998
# 2024-02-29  181.270004  182.570007  179.529999  180.750000  180.750000
# 2024-03-01  179.550003  180.529999  177.380005  179.660004  179.660004
# 2024-03-04  176.149994  176.899994  173.789993  175.100006  175.100006
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  170.119995
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
#
#                Volume company_name
# Date
# 2024-02-26   40867400        APPLE
# ...

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()
plt.savefig("Pictures/5.png")

# %%
ma_day = [10, 20, 50]
# Calculate moving averages for each day for each company
for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# Plot the adjusted close price and moving averages for the desired company (e.g., APPLE)
plt.figure(figsize=(15, 10))
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot()
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/9.png")

# Show the plot
plt.show()

# %%
# Calculate daily return percentage for the company
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# Plot the daily return percentage
plt.figure(figsize=(15, 10))
AAPL['Daily Return'].plot(legend=True, linestyle='--', marker='o')
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/13.png")

# Show the plot
plt.show()

# %%
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
yf.pdr_override()

# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['GOOG']

# Set up End and Start times for data grab
tech_list = ['GOOG']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [GOOG]
company_name = ["GOOG"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-26  143.449997  143.839996  138.740005  138.750000  138.750000
# 2024-02-27  139.410004  140.490005  138.500000  140.100006  140.100006
# 2024-02-28  139.100006  139.279999  136.639999  137.429993  137.429993
# 2024-02-29  138.350006  139.949997  137.570007  139.779999  139.779999
# 2024-03-01  139.610001  140.000000  137.975006  138.080002  138.080002
# 2024-03-04  136.539993  136.630005  132.860001  134.199997  134.199997
# 2024-03-05  132.740005  134.020004  131.550003  133.779999  133.779999
# 2024-03-06  134.240005  134.740005  131.949997  132.559998  132.559998
# 2024-03-07  133.889999  135.820007  132.660004  135.240005  135.240005
# 2024-03-08  135.035004  138.985001  134.800003  136.289993  136.289993
#
#               Volume company_name
# Date
# 2024-02-26  33513000         GOOG
# ...

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()
plt.savefig("Pictures/6.png")

# %%
for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# Plot the adjusted close price and moving averages for the desired company (e.g., APPLE)
plt.figure(figsize=(15, 10))
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot()
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/10.png")

# Show the plot
plt.show()

# %%
# Calculate daily return percentage for the company
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# Plot the daily return percentage
plt.figure(figsize=(15, 10))
AAPL['Daily Return'].plot(legend=True, linestyle='--', marker='o')
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/14.png")

# Show the plot
plt.show()

# %%
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
yf.pdr_override()

# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['MSFT']

# Set up End and Start times for data grab
tech_list = ['MSFT']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [MSFT]
company_name = ["MSFT"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-26  411.459991  412.160004  407.359985  407.540009  407.540009
# 2024-02-27  407.989990  408.320007  403.850006  407.480011  407.480011
# 2024-02-28  408.179993  409.299988  405.320007  407.720001  407.720001
# 2024-02-29  408.640015  414.200012  405.920013  413.640015  413.640015
# 2024-03-01  411.269989  415.869995  410.880005  415.500000  415.500000
# 2024-03-04  413.440002  417.350006  412.320007  414.920013  414.920013
# 2024-03-05  413.959991  414.250000  400.640015  402.649994  402.649994
# 2024-03-06  402.970001  405.160004  398.390015  402.089996  402.089996
# 2024-03-07  406.119995  409.779999  402.239990  409.140015  409.140015
# 2024-03-08  407.959991  410.420013  404.329987  406.220001  406.220001
#
#               Volume company_name
# Date
# 2024-02-26  16193500         MSFT
# ...

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()
plt.savefig("Pictures/7.png")

# %%
for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# Plot the adjusted close price and moving averages for the desired company (e.g., APPLE)
plt.figure(figsize=(15, 10))
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot()
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/11.png")

# Show the plot
plt.show()

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# Plot the daily return percentage
plt.figure(figsize=(15, 10))
AAPL['Daily Return'].plot(legend=True, linestyle='--', marker='o')
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/15.png")

# Show the plot
plt.show()

# %%
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
yf.pdr_override()

# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['AMZN']

# Set up End and Start times for data grab
tech_list = ['AMZN']

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [AMZN]
company_name = ["AMZN"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-02-26  175.699997  176.369995  174.259995  174.729996  174.729996
# 2024-02-27  174.080002  174.619995  172.860001  173.539993  173.539993
# 2024-02-28  172.440002  174.050003  172.270004  173.160004  173.160004
# 2024-02-29  173.009995  177.220001  172.850006  176.759995  176.759995
# 2024-03-01  176.750000  178.729996  176.070007  178.220001  178.220001
# 2024-03-04  177.529999  180.139999  177.490005  177.580002  177.580002
# 2024-03-05  176.929993  176.929993  173.300003  174.119995  174.119995
# 2024-03-06  175.539993  176.460007  173.259995  173.509995  173.509995
# 2024-03-07  174.830002  177.990005  173.720001  176.820007  176.820007
# 2024-03-08  176.440002  178.789993  174.330002  175.350006  175.350006
#
#               Volume company_name
# Date
# 2024-02-26  44368600         AMZN
# ...

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()
plt.savefig("Pictures/8.png")

# %%
for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# Plot the adjusted close price and moving averages for the desired company (e.g., APPLE)
plt.figure(figsize=(15, 10))
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot()
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/12.png")

# Show the plot
plt.show()

# %%
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# Plot the daily return percentage
plt.figure(figsize=(15, 10))
AAPL['Daily Return'].plot(legend=True, linestyle='--', marker='o')
plt.title('APPLE')
plt.tight_layout()

# Save the plot to a file
plt.savefig("Pictures/16.png")

# Show the plot
plt.show()

# %%
# Get the stock quote
df = pdr.get_data_yahoo('AAPL', start='2012-01-01', end=datetime.now())
# Show teh data
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   14.621429   14.732143   14.607143   14.686786   12.433825
# 2012-01-04   14.642857   14.810000   14.617143   14.765714   12.500644
# 2012-01-05   14.819643   14.948214   14.738214   14.929643   12.639428
# 2012-01-06   14.991786   15.098214   14.972143   15.085714   12.771560
# 2012-01-09   15.196429   15.276786   15.048214   15.061786   12.751298
# ...                ...         ...         ...         ...         ...
# 2024-03-04  176.149994  176.899994  173.789993  175.100006  175.100006
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  170.119995
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
#
#                Volume
# Date
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 2912

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00401431],
#        [0.00444289],
#        [0.00533302],
#        ...,
#        [0.84258464],
#        [0.84193307],
#        [0.85132693]])

# %%
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.00401431, 0.00444289, 0.00533302, 0.00618049, 0.00605056,
#        0.00634339, 0.00620958, 0.00598462, 0.00567821, 0.00662652,
#        0.00748175, 0.007218  , 0.00577323, 0.00715207, 0.00579457,
#        0.01088518, 0.01049151, 0.01100542, 0.01211663, 0.01278955,
#        0.01273332, 0.01252582, 0.01341013, 0.01424207, 0.01518457,
#        0.01670691, 0.01990478, 0.01995326, 0.02173353, 0.02306387,
#        0.02077746, 0.02165789, 0.02164044, 0.02410915, 0.02375813,
#        0.02440779, 0.02557523, 0.0262249 , 0.02809631, 0.02945961,
#        0.02985329, 0.02999098, 0.02765997, 0.02709757, 0.02718096,
#        0.02937236, 0.02998905, 0.03131358, 0.03443581, 0.03860139,
#        0.0378218 , 0.03782373, 0.04083544, 0.04177794, 0.04110694,
#        0.04049413, 0.03985611, 0.04197573, 0.0434302 , 0.04403914])]
# [0.042534249860459186]
#
# [array([0.00401431, 0.00444289, 0.00533302, 0.00618049, 0.00605056,
#        0.00634339, 0.00620958, 0.00598462, 0.00567821, 0.00662652,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# c:\Users\sriva\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2852/2852 ━━━━━━━━━━━━━━━━━━━━ 112s 36ms/step - loss: 0.0020

# %%
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
print(len(x_test))
# Convert the data to a numpy array
x_test = np.array(x_test)


# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 153
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4.988030516381047

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\sriva\AppData\Local\Temp\ipykernel_10528\2388977846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
import numpy as np

# Define the number of future time steps you want to predict
future_steps = 20  # Change this number to predict more or fewer future steps

# Get the last sequence from the test data
last_sequence = x_test[-1]

# Create a list to store the predicted future values
future_predictions = []

# Predict future values
for i in range(future_steps):
    # Reshape the last sequence to match the model's input shape
    last_sequence_reshaped = last_sequence.reshape((1, last_sequence.shape[0], 1))
    
    # Predict the next value
    next_prediction = model.predict(last_sequence_reshaped)
    
    # Append the prediction to the list of future predictions
    future_predictions.append(next_prediction[0][0])
    
    # Update the last sequence by removing the first element and appending the predicted value
    last_sequence = np.append(last_sequence[1:], next_prediction)

# Convert the list of future predictions to a numpy array
future_predictions = np.array(future_predictions)

# Inverse transform the predictions to get the actual values
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1))

# Print the future predictions
print("Future Predictions:")
print(future_predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Future Predictions:
# [[168.439  ]
#  [166.93231]
#  [165.70602]
#  [164.63432]
#  [163.65634]
#  [162.73997]
#  [161.86656]
#  [161.02429]
#  [160.20523]
#  [159.40407]
#  [158.61713]
# ...

# %%
import matplotlib.pyplot as plt

# Extend the x-axis for future predictions
future_dates = np.arange(len(data), len(data) + future_steps)

# Plot the data and predictions
plt.figure(figsize=(16, 6))
plt.plot(data, label='Original Data')
plt.plot(train.index, train['Close'], label='Training Data', color='blue')
plt.plot(valid.index, valid['Close'], label='Validation Data', color='green')
plt.plot(valid.index, valid['Predictions'], label='Predictions', color='red')
plt.plot(future_dates, future_predictions, label='Future Predictions', color='orange')
plt.title('Model Predictions and Future Predictions')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Extend the dates for future predictions
future_dates = pd.date_range(start=valid.index[-1] + pd.Timedelta(days=1), periods=future_steps)

# Plot the data and predictions
plt.figure(figsize=(16, 6))
plt.plot(train.index, train['Close'], label='Train',color='blue')
plt.plot(valid.index, valid['Predictions'], label='Predictions',color='green')
plt.plot(future_dates, future_predictions, label='Future Predictions',color='green')
plt.title('Model Predictions and Future Predictions')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.savefig("Pictures/17.png")
plt.show()
